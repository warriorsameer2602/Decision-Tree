# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\samee\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\samee\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in c:\users\samee\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\samee\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\samee\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\samee\appdata\roaming\python\python314\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.tokenize import word_tokenize 
from nltk import ngrams

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\samee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\samee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
def generate_ngrams(text, n):
    tokens = word_tokenize(text)
    n_grams = list(ngrams(tokens,n))
    return n_grams

# %%
# some examples
txt = "Sameer is a Iron man and He is a genius guy and a amazing man"
unigrams = generate_ngrams(txt,1)
bigrams = generate_ngrams(txt,2)
trigrams = generate_ngrams(txt,3)

# %%
print(unigrams)
# Out:
# [('Sameer',), ('is',), ('a',), ('Iron',), ('man',), ('and',), ('He',), ('is',), ('a',), ('genius',), ('guy',), ('and',), ('a',), ('amazing',), ('man',)]

# %%
print(bigrams)
# Out:
# [('Sameer', 'is'), ('is', 'a'), ('a', 'Iron'), ('Iron', 'man'), ('man', 'and'), ('and', 'He'), ('He', 'is'), ('is', 'a'), ('a', 'genius'), ('genius', 'guy'), ('guy', 'and'), ('and', 'a'), ('a', 'amazing'), ('amazing', 'man')]

# %%
print(trigrams)
# Out:
# [('Sameer', 'is', 'a'), ('is', 'a', 'Iron'), ('a', 'Iron', 'man'), ('Iron', 'man', 'and'), ('man', 'and', 'He'), ('and', 'He', 'is'), ('He', 'is', 'a'), ('is', 'a', 'genius'), ('a', 'genius', 'guy'), ('genius', 'guy', 'and'), ('guy', 'and', 'a'), ('and', 'a', 'amazing'), ('a', 'amazing', 'man')]
